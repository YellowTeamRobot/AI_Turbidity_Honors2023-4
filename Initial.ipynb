# %%
import os
from PIL import Image
import csv

# Function to extract metadata from an image
def extract_image_metadata(image_path):
    try:
        with Image.open(image_path) as img:
            metadata = {
                "ISO": img._getexif().get(34855),  # ISO
                "ShutterSpeed": img._getexif().get(33434),  # Shutter Speed
                "FocalLength": img._getexif().get(37386),  # Focal Length
                "FStop": img._getexif().get(33437),  # F-Stop
                "WhiteBalance": img._getexif().get(41987)  # White Balance
            }
            return metadata
    except (AttributeError, FileNotFoundError, IsADirectoryError, PermissionError):
        return None

# Folder containing the images
image_folder = "/home/twilight/Honors Research Project/AI_Turbidity_Honors2023-4/Datasets/With Secchi/2023-10-5-4gal-inkAndSediment1"

# Output CSV file
csv_file = "output.csv"

# Get a list of image files in the folder
image_files = [file for file in os.listdir(image_folder) if file.lower().endswith(('jpg', 'jpeg', 'png', 'gif', 'bmp'))]

# Prepare the CSV header and rows
header = ["Image Name", "Site", "Substrate", "Auto", "ISO", "ShutterSpeed", "FocalLength", "FStop", "WhiteBalance", "FNU", "DOC", "Flow", "Secchi", "TSS"]
rows = []

# Iterate through image files and extract metadata
for image_name in image_files:
    image_path = os.path.join(image_folder, image_name)
    metadata = extract_image_metadata(image_path)

    # Append a row for each image
    rows.append([image_name, "", "", "", metadata["ISO"] if metadata else "", metadata["ShutterSpeed"] if metadata else "",
                 metadata["FocalLength"] if metadata else "", metadata["FStop"] if metadata else "",
                 metadata["WhiteBalance"] if metadata else "", "", "", "", "", ""])

# Write to CSV
with open(csv_file, mode='w', newline='') as file:
    writer = csv.writer(file)
    writer.writerow(header)
    writer.writerows(rows)

print("CSV file created successfully:", csv_file)
# Out:
# CSV file created successfully: output.csv

# %% [markdown]
# # Make sure to add values and tidy up the csv in excel, and also rename

# %% [markdown]
# ### Code for splitting all pictures in a master dataset folder into range folders

# %%
# 5 categories
folder_ranges = [(0, 10), (11, 21), (22, 32), (33, 43), (44, 55)]

# %%
# 11 categories
folder_ranges = [(0, 5), (6, 10), (11, 15), (16, 20), (21, 25), (26,30), (31,35), (36,40), (41,45), (46,50), (51,55)]

# %%
# Input CSV file
csv_file = "./Datasets/With Secchi/_Master-Secchi.csv"

# %%
# Specify the parent directory where you want to create the folders
parent_directory = "./Datasets/With Secchi/"

# %%
# Specify path to input folder of images
image_folder = "./Datasets/With Secchi/_Master/"

# %%
import os
import shutil
import csv


for start, end in folder_ranges:
    folder_name = f"{start}-{end}"
    os.makedirs(os.path.join(parent_directory, folder_name), exist_ok=True)

# Read the CSV file and copy images to the corresponding folders
with open(csv_file, 'r') as file:
    reader = csv.reader(file)
    header = next(reader)  # Skip header

    for row in reader:
        image_name = row[0]
        fnu_value = float(row[9])  # FNU column

        # Determine the folder based on the FNU value
        for start, end in folder_ranges:
            if start <= fnu_value <= end:
                destination_folder = f"{start}-{end}"
                break

        # Copy the image to the corresponding folder
        source_path = os.path.join(image_folder, image_name)  # Update with your image folder path
        destination_path = os.path.join(parent_directory, destination_folder, image_name)

        shutil.copyfile(source_path, destination_path)

print("Images copied to the corresponding folders in:", parent_directory)
# Out:
# Images copied to the corresponding folders in: ./Datasets/With Secchi/

# %% [markdown]
# ### Code for taking the created range folders and splitting into train, test, validate folders
# ##### Likes to not put as many in Val folder with small dataset, make sure there is at least one picture in each category

# %%
import os
import shutil
import random
import math

# Source and destination directories
source_root = './Datasets/With Secchi/Grouped/'
destination_root = './Datasets/With Secchi/_Processed/'

# Percentage split for training, validation, and testing
train_percentage = 0.8  # 80% for training
test_percentage = 0.15   # 15% for testing
val_percentage = 0.05    # 5% for validation


# Create destination directories
os.makedirs(os.path.join(destination_root, 'train'), exist_ok=True)
os.makedirs(os.path.join(destination_root, 'val'), exist_ok=True)
os.makedirs(os.path.join(destination_root, 'test'), exist_ok=True)

# Iterate through each class directory in the source root
for class_name in os.listdir(source_root):
    class_source_dir = os.path.join(source_root, class_name)

    # Create destination directories for the current class
    os.makedirs(os.path.join(destination_root, 'train', class_name), exist_ok=True)
    os.makedirs(os.path.join(destination_root, 'val', class_name), exist_ok=True)
    os.makedirs(os.path.join(destination_root, 'test', class_name), exist_ok=True)

    # Get a list of all files in the current class directory
    files = os.listdir(class_source_dir)
    num_files = len(files)

    # Calculate the number of files for training, validation, and testing
    num_train = math.ceil(train_percentage * num_files)
    num_val = math.ceil(val_percentage * num_files)
    num_test = num_files - (num_train + num_val)

    # Shuffle the files randomly
    random.shuffle(files)

    # Move files for training
    for i in range(min(num_train, len(files))):
        source_file = os.path.join(class_source_dir, files[i])
        destination_file = os.path.join(destination_root, 'train', class_name, files[i])
        shutil.copy(source_file, destination_file)

    # Move files for validation
    for i in range(num_train, num_train + min(num_val, len(files) - num_train)):
        source_file = os.path.join(class_source_dir, files[i])
        destination_file = os.path.join(destination_root, 'val', class_name, files[i])
        shutil.copy(source_file, destination_file)

    # Move files for testing
    for i in range(num_train + num_val, num_train + num_val + min(num_test, len(files) - num_train - num_val)):
        source_file = os.path.join(class_source_dir, files[i])
        destination_file = os.path.join(destination_root, 'test', class_name, files[i])
        shutil.copy(source_file, destination_file)

# %% [markdown]
# -----
# ### Code for splitting and adding all at once
# #### Not as good

# %%
import os
import shutil
import csv
import random

# Input CSV file
csv_file = "./Dataset1.csv"

# Specify the parent directory where you want to create the folders
parent_directory = "./Datasets/D1Set/"

# Create folders for different FNU ranges and subsets inside the parent directory
folder_ranges = [(0, 10), (11, 21), (22, 32), (33, 43), (44, 55)]
subsets = ['train', 'test', 'validate']

for start, end in folder_ranges:
    folder_name = f"{start}-{end}"
    for subset in subsets:
        os.makedirs(os.path.join(parent_directory, subset, folder_name), exist_ok=True)

# Define the percentages for train, test, and validate
train_percentage = 0.7
test_percentage = 0.3
validate_percentage = 0.00

# Initialize counters for each FNU range and subset
counters = {range_: {subset: 0 for subset in subsets} for range_ in folder_ranges}

# Read the CSV file and copy images to the corresponding folders
with open(csv_file, 'r') as file:
    reader = csv.reader(file)
    header = next(reader)  # Skip header

    for row in reader:
        image_name = row[0]
        fnu_value = float(row[9])  # FNU column

        # Determine the folder based on the FNU value
        for start, end in folder_ranges:
            if start <= fnu_value <= end:
                fnu_range = (start, end)
                break

        # Determine the subset based on the counters and percentages
        rand_num = random.random()
        if rand_num < train_percentage and counters[fnu_range]['train'] < train_percentage * 100:
            subset_folder = 'train'
        elif rand_num < train_percentage + test_percentage and counters[fnu_range]['test'] < test_percentage * 100:
            subset_folder = 'test'
        elif counters[fnu_range]['validate'] < validate_percentage * 100:
            subset_folder = 'validate'
        else:
            subset_folder = 'train'  # Default to 'train' if not within the percentages

        # Update the counters and copy the image to the corresponding subset folder
        counters[fnu_range][subset_folder] += 1
        destination_folder = f"{fnu_range[0]}-{fnu_range[1]}"
        source_path = os.path.join("./Datasets/Dataset1", image_name)  # Update with your image folder path
        destination_path = os.path.join(parent_directory, subset_folder, destination_folder, image_name)

        shutil.copyfile(source_path, destination_path)

print("Images copied to the corresponding folders in:", parent_directory)
# Out:
# Images copied to the corresponding folders in: ./Datasets/D1Set/

# %% [markdown]
# # Now for training classification Model

# %%
import torch
torch.cuda.is_available()
# Out:
# True

# %%
from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.138 🚀 Python-3.11.4 torch-2.0.1 CUDA:0 (NVIDIA GeForce RTX 4080, 16376MiB)
# Setup complete ✅ (24 CPUs, 30.9 GB RAM, 113.9/1006.9 GB disk)

# %%
from ultralytics import YOLO

from IPython.display import display, Image

# %%
import numpy
numpy.version.version
# Out:
# '1.25.0'

# %%
#%cd '/content'
# Train Initial
# !yolo task=classify mode=train model='yolov8l-cls.pt' data="./Datasets/With Secchi/_Processed" epochs=500 imgsz=320 patience=0 project="./Training/2023-10-8" #resume model="./FirstTrain/something.pt"
# Out:
# WARNING ⚠️ 'ultralytics.yolo.v8' is deprecated since '8.0.136' and will be removed in '8.1.0'. Please use 'ultralytics.models.yolo' instead.
# WARNING ⚠️ 'ultralytics.yolo.cfg' is deprecated since '8.0.136' and will be removed in '8.1.0'. Please use 'ultralytics.cfg' instead.
# New https://pypi.org/project/ultralytics/8.0.195 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.138 🚀 Python-3.11.4 torch-2.0.1 CUDA:0 (NVIDIA GeForce RTX 4080, 16376MiB)
# engine/trainer: task=classify, mode=train, model=yolov8l-cls.pt, data=./Datasets/With Secchi/_Processed, epochs=500, patience=0, batch=16, imgsz=320, save=True, save_period=-1, cache=False, device=None, workers=8, project=./Training/2023-10-8, name=None, exist_ok=False, pretrained=True, optimizer=auto, verbose=True, seed=0, deterministic=True, single_cls=False, rect=False, cos_lr=False, close_mosaic=10, resume=False, amp=True, fraction=1.0, profile=False, overlap_mask=True, mask_ratio=4, dropout=0.0, val=True, split=val, save_json=False, save_hybrid=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, show=False, save_txt=False, save_conf=False, save_crop=False, show_labels=True, show_conf=True, vid_stride=1, line_width=None, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, boxes=True, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=False, opset=None, workspace=4, nms=False, lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, pose=12.0, kobj=1.0, label_smoothing=0.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0, cfg=None, tracker=botsort.yaml, save_dir=Training/2023-10-8/train
# Overriding model.yaml nc=1000 with nc=5
#
#                    from  n    params  module                                       arguments
#   0                  -1  1      1856  ultralytics.nn.modules.conv.Conv             [3, 64, 3, 2]
#   1                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   2                  -1  3    279808  ultralytics.nn.modules.block.C2f             [128, 128, 3, True]
#   3                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   4                  -1  6   2101248  ultralytics.nn.modules.block.C2f             [256, 256, 6, True]
#   5                  -1  1   1180672  ultralytics.nn.modules.conv.Conv             [256, 512, 3, 2]
#   6                  -1  6   8396800  ultralytics.nn.modules.block.C2f             [512, 512, 6, True]
#   7                  -1  1   4720640  ultralytics.nn.modules.conv.Conv             [512, 1024, 3, 2]
#   8                  -1  3  17836032  ultralytics.nn.modules.block.C2f             [1024, 1024, 3, True]
#   9                  -1  1   1319685  ultralytics.nn.modules.head.Classify         [1024, 5]
# YOLOv8l-cls summary: 183 layers, 36206149 parameters, 36206149 gradients
# Transferred 300/302 items from pretrained weights
# AMP: running Automatic Mixed Precision (AMP) checks with YOLOv8n...
# /home/twilight/anaconda3/envs/USDA2023/lib/python3.11/site-packages/torch/nn/modules/conv.py:459: UserWarning: Applied workaround for CuDNN issue, install nvrtc.so (Triggered internally at /opt/conda/conda-bld/pytorch_1682343995622/work/aten/src/ATen/native/cudnn/Conv_v8.cpp:80.)
#   return F.conv2d(input, weight, bias, self.stride,
# AMP: checks passed ✅
# optimizer: AdamW(lr=0.000714, momentum=0.9) with parameter groups 50 weight(decay=0.0), 51 weight(decay=0.0005), 51 bias(decay=0.0)
# Image sizes 320 train, 320 val
# Using 8 dataloader workers
# Logging results to Training/2023-10-8/train
# Starting training for 500 epochs...
#
#       Epoch    GPU_mem       loss  Instances       Size
#       1/500      2.57G     0.3186          6        320: 100%|██████████| 4/4 [0
#                classes   top1_acc   top5_acc: 100%|██████████| 1/1 [00:00<00:00,
#                    all        0.5          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       2/500       2.6G     0.2677          6        320: 100%|██████████| 4/4 [0
#                classes   top1_acc   top5_acc: 100%|██████████| 1/1 [00:00<00:00,
#                    all      0.375          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       3/500      2.61G     0.1648          6        320: 100%|██████████| 4/4 [0
#                classes   top1_acc   top5_acc: 100%|██████████| 1/1 [00:00<00:00,
#                    all       0.25          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       4/500      2.62G    0.07624          6        320: 100%|██████████| 4/4 [0
#                classes   top1_acc   top5_acc: 100%|██████████| 1/1 [00:00<00:00,
#                    all      0.625          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       5/500      2.64G    0.04335          6        320: 100%|██████████| 4/4 [0
#                classes   top1_acc   top5_acc: 100%|██████████| 1/1 [00:00<00:00,
#                    all      0.625          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       6/500      2.64G    0.02171          6        320: 100%|██████████| 4/4 [0
#                classes   top1_acc   top5_acc: 100%|██████████| 1/1 [00:00<00:00,
#                    all       0.75          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       7/500      2.64G    0.01343          6        320: 100%|██████████| 4/4 [0
#                classes   top1_acc   top5_acc: 100%|██████████| 1/1 [00:00<00:00,
#                    all       0.75          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       8/500      2.63G   0.007748          6        320: 100%|██████████| 4/4 [0
#                classes   top1_acc   top5_acc: 100%|██████████| 1/1 [00:00<00:00,
#                    all       0.75          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       9/500      2.62G   0.005159          6        320: 100%|██████████| 4/4 [0
#                classes   top1_acc   top5_acc: 100%|██████████| 1/1 [00:00<00:00,
#                    all       0.75          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      10/500      2.62G   0.006533          6        320: 100%|██████████| 4/4 [0
#                classes   top1_acc   top5_acc: 100%|██████████| 1/1 [00:00<00:00,
#                    all       0.75          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      11/500      2.63G   0.003833          6        320: 100%|██████████| 4/4 [0
#                classes   top1_acc   top5_acc: 100%|██████████| 1/1 [00:00<00:00,
#                    all       0.75          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      12/500      2.63G   0.001418          6        320: 100%|██████████| 4/4 [0
#                classes   top1_acc   top5_acc: 100%|██████████| 1/1 [00:00<00:00,
#                    all       0.75          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      13/500      2.63G   0.001379          6        320: 100%|██████████| 4/4 [0
#                classes   top1_acc   top5_acc: 100%|██████████| 1/1 [00:00<00:00,
#                    all       0.75          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      14/500      2.62G  0.0005533          6        320: 100%|██████████| 4/4 [0
#                classes   top1_acc   top5_acc: 100%|██████████| 1/1 [00:00<00:00,
#                    all       0.75          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      15/500      2.63G    0.00061          6        320: 100%|██████████| 4/4 [0
#                classes   top1_acc   top5_acc: 100%|██████████| 1/1 [00:00<00:00,
#                    all       0.75          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      16/500      2.64G   0.000732          6        320: 100%|██████████| 4/4 [0
#                classes   top1_acc   top5_acc: 100%|██████████| 1/1 [00:00<00:00,
#                    all       0.75          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      17/500      2.62G  0.0002464          6        320: 100%|██████████| 4/4 [0
#                classes   top1_acc   top5_acc: 100%|██████████| 1/1 [00:00<00:00,
#                    all       0.75          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      18/500      2.62G  0.0002207          6        320: 100%|██████████| 4/4 [0
#                classes   top1_acc   top5_acc: 100%|██████████| 1/1 [00:00<00:00,
#                    all       0.75          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      19/500      2.63G   0.005547          6        320: 100%|██████████| 4/4 [0
#                classes   top1_acc   top5_acc: 100%|██████████| 1/1 [00:00<00:00,
#                    all       0.75          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      20/500      2.64G   0.001281          6        320: 100%|██████████| 4/4 [0
#                classes   top1_acc   top5_acc: 100%|██████████| 1/1 [00:00<00:00,
#                    all       0.75          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      21/500      2.62G   0.009484          6        320: 100%|██████████| 4/4 [0
#                classes   top1_acc   top5_acc: 100%|██████████| 1/1 [00:00<00:00,
#                    all       0.75          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      22/500      2.62G  0.0001852          6        320: 100%|██████████| 4/4 [0
#                classes   top1_acc   top5_acc: 100%|██████████| 1/1 [00:00<00:00,
#                    all       0.75          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      23/500      2.63G  0.0006889          6        320: 100%|██████████| 4/4 [0
#                classes   top1_acc   top5_acc: 100%|██████████| 1/1 [00:00<00:00,
#                    all       0.75          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      24/500      2.61G  0.0005776          6        320: 100%|██████████| 4/4 [0
#                classes   top1_acc   top5_acc: 100%|██████████| 1/1 [00:00<00:00,
#                    all       0.75          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      25/500      2.63G  8.484e-05          6        320: 100%|██████████| 4/4 [0
#                classes   top1_acc   top5_acc: 100%|██████████| 1/1 [00:00<00:00,
#                    all      0.875          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      26/500       2.6G  0.0001007          6        320: 100%|██████████| 4/4 [0
#                classes   top1_acc   top5_acc: 100%|██████████| 1/1 [00:00<00:00,
#                    all      0.875          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      27/500      2.63G  0.0001915          6        320: 100%|██████████| 4/4 [0
#                classes   top1_acc   top5_acc: 100%|██████████| 1/1 [00:00<00:00,
#                    all      0.875          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      28/500      2.62G  0.0007086          6        320: 100%|██████████| 4/4 [0
#                classes   top1_acc   top5_acc: 100%|██████████| 1/1 [00:00<00:00,
#                    all      0.875          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      29/500      2.62G  0.0001708          6        320: 100%|██████████| 4/4 [0
#                classes   top1_acc   top5_acc: 100%|██████████| 1/1 [00:00<00:00,
#                    all      0.875          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      30/500      2.63G      0.059          6        320: 100%|██████████| 4/4 [0
#                classes   top1_acc   top5_acc: 100%|██████████| 1/1 [00:00<00:00,
#                    all       0.75          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      31/500      2.62G   0.002607          6        320: 100%|██████████| 4/4 [0
#                classes   top1_acc   top5_acc: 100%|██████████| 1/1 [00:00<00:00,
#                    all      0.625          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      32/500      2.62G    0.02263          6        320: 100%|██████████| 4/4 [0
#                classes   top1_acc   top5_acc: 100%|██████████| 1/1 [00:00<00:00,
#                    all       0.75          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      33/500      2.63G   0.009264          6        320: 100%|██████████| 4/4 [0
#                classes   top1_acc   top5_acc: 100%|██████████| 1/1 [00:00<00:00,
#                    all       0.75          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      34/500      2.62G   0.002503          6        320: 100%|██████████| 4/4 [0
#                classes   top1_acc   top5_acc: 100%|██████████| 1/1 [00:00<00:00,
#                    all       0.75          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      35/500      2.62G    0.01086          6        320: 100%|██████████| 4/4 [0
#                classes   top1_acc   top5_acc: 100%|██████████| 1/1 [00:00<00:00,
#                    all      0.625          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      36/500      2.62G   0.003876          6        320: 100%|██████████| 4/4 [0
#                classes   top1_acc   top5_acc: 100%|██████████| 1/1 [00:00<00:00,
#                    all      0.625          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      37/500      2.64G   0.003915          6        320: 100%|██████████| 4/4 [0
#                classes   top1_acc   top5_acc: 100%|██████████| 1/1 [00:00<00:00,
#                    all       0.75          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      38/500      2.62G   0.001905          6        320: 100%|██████████| 4/4 [0
#                classes   top1_acc   top5_acc: 100%|██████████| 1/1 [00:00<00:00,
#                    all       0.75          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      39/500      2.62G   0.001401          6        320: 100%|██████████| 4/4 [0
#                classes   top1_acc   top5_acc: 100%|██████████| 1/1 [00:00<00:00,
#                    all       0.75          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      40/500      2.62G    0.01015          6        320: 100%|██████████| 4/4 [0
#                classes   top1_acc   top5_acc: 100%|██████████| 1/1 [00:00<00:00,
#                    all       0.75          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      41/500      2.62G    0.04377          6        320: 100%|██████████| 4/4 [0
#                classes   top1_acc   top5_acc: 100%|██████████| 1/1 [00:00<00:00,
#                    all      0.875          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      42/500      2.62G    0.01024          6        320: 100%|██████████| 4/4 [0
#                classes   top1_acc   top5_acc: 100%|██████████| 1/1 [00:00<00:00,
#                    all       0.75          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      43/500      2.62G   0.001363          6        320: 100%|██████████| 4/4 [0
#                classes   top1_acc   top5_acc: 100%|██████████| 1/1 [00:00<00:00,
#                    all      0.625          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      44/500      2.62G    0.02729          6        320: 100%|██████████| 4/4 [0
#                classes   top1_acc   top5_acc: 100%|██████████| 1/1 [00:00<00:00,
#                    all       0.75          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      45/500      2.62G   0.006834          6        320: 100%|██████████| 4/4 [0
#                classes   top1_acc   top5_acc: 100%|██████████| 1/1 [00:00<00:00,
#                    all      0.625          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      46/500      2.62G    0.02387          6        320: 100%|██████████| 4/4 [0
#                classes   top1_acc   top5_acc: 100%|██████████| 1/1 [00:00<00:00,
#                    all       0.75          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      47/500      2.62G    0.01041          6        320: 100%|██████████| 4/4 [0
#                classes   top1_acc   top5_acc: 100%|██████████| 1/1 [00:00<00:00,
#                    all       0.75          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      48/500      2.62G    0.01374          6        320: 100%|██████████| 4/4 [0
#                classes   top1_acc   top5_acc: 100%|██████████| 1/1 [00:00<00:00,
#                    all       0.75          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      49/500      2.62G    0.04287          6        320: 100%|██████████| 4/4 [0
#                classes   top1_acc   top5_acc: 100%|██████████| 1/1 [00:00<00:00,
#                    all      0.875          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      50/500      2.62G    0.01356          6        320: 100%|██████████| 4/4 [0
#                classes   top1_acc   top5_acc: 100%|██████████| 1/1 [00:00<00:00,
#                    all       0.75          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      51/500      2.62G   0.008064          6        320: 100%|██████████| 4/4 [0
#                classes   top1_acc   top5_acc: 100%|██████████| 1/1 [00:00<00:00,
#                    all       0.75          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      52/500      2.62G    0.01082          6        320: 100%|██████████| 4/4 [0
#                classes   top1_acc   top5_acc: 100%|██████████| 1/1 [00:00<00:00,
#                    all       0.75          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      53/500      2.62G   0.003364          6        320: 100%|██████████| 4/4 [0
#                classes   top1_acc   top5_acc: 100%|██████████| 1/1 [00:00<00:00,
#                    all       0.75          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      54/500      2.62G   0.001901          6        320: 100%|██████████| 4/4 [0
#                classes   top1_acc   top5_acc: 100%|██████████| 1/1 [00:00<00:00,
#                    all       0.75          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      55/500      2.62G  0.0006795          6        320: 100%|██████████| 4/4 [0
#                classes   top1_acc   top5_acc: 100%|██████████| 1/1 [00:00<00:00,
#                    all       0.75          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      56/500      2.62G  0.0007109          6        320: 100%|██████████| 4/4 [0
#                classes   top1_acc   top5_acc: 100%|██████████| 1/1 [00:00<00:00,
#                    all      0.625          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      57/500      2.62G    0.00208          6        320: 100%|██████████| 4/4 [0
#                classes   top1_acc   top5_acc: 100%|██████████| 1/1 [00:00<00:00,
#                    all      0.625          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      58/500      2.62G  0.0003992          6        320: 100%|██████████| 4/4 [0
#                classes   top1_acc   top5_acc: 100%|██████████| 1/1 [00:00<00:00,
#                    all      0.625          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      59/500      2.62G  0.0003571          6        320: 100%|██████████| 4/4 [0
#                classes   top1_acc   top5_acc: 100%|██████████| 1/1 [00:00<00:00,
#                    all      0.625          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      60/500      2.62G  0.0004023          6        320: 100%|██████████| 4/4 [0
#                classes   top1_acc   top5_acc: 100%|██████████| 1/1 [00:00<00:00,
#                    all      0.625          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      61/500      2.62G   0.001451          6        320: 100%|██████████| 4/4 [0
#                classes   top1_acc   top5_acc: 100%|██████████| 1/1 [00:00<00:00,
#                    all      0.625          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      62/500      2.62G  0.0002056          6        320: 100%|██████████| 4/4 [0
#                classes   top1_acc   top5_acc: 100%|██████████| 1/1 [00:00<00:00,
#                    all      0.625          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      63/500      2.63G  0.0009886          6        320: 100%|██████████| 4/4 [0
#                classes   top1_acc   top5_acc: 100%|██████████| 1/1 [00:00<00:00,
#                    all       0.75          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      64/500      2.62G  0.0006369          6        320: 100%|██████████| 4/4 [0
#                classes   top1_acc   top5_acc: 100%|██████████| 1/1 [00:00<00:00,
#                    all      0.875          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      65/500      2.62G   0.001231          6        320: 100%|██████████| 4/4 [0
#                classes   top1_acc   top5_acc: 100%|██████████| 1/1 [00:00<00:00,
#                    all      0.875          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      66/500      2.62G  0.0002556          6        320: 100%|██████████| 4/4 [0
#                classes   top1_acc   top5_acc: 100%|██████████| 1/1 [00:00<00:00,
#                    all      0.875          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      67/500      2.62G  0.0002912          6        320: 100%|██████████| 4/4 [0
#                classes   top1_acc   top5_acc: 100%|██████████| 1/1 [00:00<00:00,
#                    all       0.75          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      68/500      2.62G  0.0007666          6        320: 100%|██████████| 4/4 [0
#                classes   top1_acc   top5_acc: 100%|██████████| 1/1 [00:00<00:00,
#                    all       0.75          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      69/500      2.62G   0.008887          6        320: 100%|██████████| 4/4 [0
#                classes   top1_acc   top5_acc: 100%|██████████| 1/1 [00:00<00:00,
#                    all      0.625          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      70/500      2.62G   0.001508          6        320: 100%|██████████| 4/4 [0
#                classes   top1_acc   top5_acc: 100%|██████████| 1/1 [00:00<00:00,
#                    all       0.75          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      71/500      2.62G    0.03102          6        320: 100%|██████████| 4/4 [0
#                classes   top1_acc   top5_acc: 100%|██████████| 1/1 [00:00<00:00,
#                    all      0.875          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      72/500      2.62G   0.001164          6        320: 100%|██████████| 4/4 [0
#                classes   top1_acc   top5_acc: 100%|██████████| 1/1 [00:00<00:00,
#                    all      0.875          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      73/500      2.62G    0.02576          6        320: 100%|██████████| 4/4 [0
#                classes   top1_acc   top5_acc: 100%|██████████| 1/1 [00:00<00:00,
#                    all      0.875          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      74/500      2.62G   0.005137          6        320: 100%|██████████| 4/4 [0
#                classes   top1_acc   top5_acc: 100%|██████████| 1/1 [00:00<00:00,
#                    all      0.875          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      75/500      2.62G     0.0168          6        320: 100%|██████████| 4/4 [0
#                classes   top1_acc   top5_acc: 100%|██████████| 1/1 [00:00<00:00,
#                    all       0.75          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      76/500      2.62G   0.002828          6        320: 100%|██████████| 4/4 [0
#                classes   top1_acc   top5_acc: 100%|██████████| 1/1 [00:00<00:00,
#                    all      0.625          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      77/500      2.62G   0.002594          6        320: 100%|██████████| 4/4 [0
#                classes   top1_acc   top5_acc: 100%|██████████| 1/1 [00:00<00:00,
#                    all      0.625          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      78/500      2.62G   0.006712          6        320: 100%|██████████| 4/4 [0
#                classes   top1_acc   top5_acc: 100%|██████████| 1/1 [00:00<00:00,
#                    all      0.625          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      79/500      2.62G   0.007227          6        320: 100%|██████████| 4/4 [0
#                classes   top1_acc   top5_acc: 100%|██████████| 1/1 [00:00<00:00,
#                    all      0.625          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      80/500      2.62G   0.001363          6        320: 100%|██████████| 4/4 [0
#                classes   top1_acc   top5_acc: 100%|██████████| 1/1 [00:00<00:00,
#                    all       0.75          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      81/500      2.62G   0.002074          6        320: 100%|██████████| 4/4 [0
#                classes   top1_acc   top5_acc: 100%|██████████| 1/1 [00:00<00:00,
#                    all       0.75          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      82/500      2.62G   0.003176          6        320: 100%|██████████| 4/4 [0
#                classes   top1_acc   top5_acc: 100%|██████████| 1/1 [00:00<00:00,
#                    all       0.75          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      83/500      2.62G   0.005263          6        320: 100%|██████████| 4/4 [0
#                classes   top1_acc   top5_acc: 100%|██████████| 1/1 [00:00<00:00,
#                    all      0.625          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      84/500      2.62G   0.002837          6        320: 100%|██████████| 4/4 [0
#                classes   top1_acc   top5_acc: 100%|██████████| 1/1 [00:00<00:00,
#                    all        0.5          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      85/500      2.62G    0.01172          6        320: 100%|██████████| 4/4 [0
#                classes   top1_acc   top5_acc: 100%|██████████| 1/1 [00:00<00:00,
#                    all      0.625          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      86/500      2.62G   0.001217          6        320: 100%|██████████| 4/4 [0
#                classes   top1_acc   top5_acc: 100%|██████████| 1/1 [00:00<00:00,
#                    all      0.625          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      87/500      2.62G  0.0007246          6        320: 100%|██████████| 4/4 [0
#                classes   top1_acc   top5_acc: 100%|██████████| 1/1 [00:00<00:00,
#                    all      0.625          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      88/500      2.62G   0.001632          6        320: 100%|██████████| 4/4 [0
#                classes   top1_acc   top5_acc: 100%|██████████| 1/1 [00:00<00:00,
#                    all      0.625          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      89/500      2.62G    0.00128          6        320: 100%|██████████| 4/4 [0
#                classes   top1_acc   top5_acc: 100%|██████████| 1/1 [00:00<00:00,
#                    all      0.625          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      90/500      2.62G   0.001115          6        320: 100%|██████████| 4/4 [0
#                classes   top1_acc   top5_acc: 100%|██████████| 1/1 [00:00<00:00,
#                    all       0.75          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      91/500      2.62G  0.0009556          6        320: 100%|██████████| 4/4 [0
#                classes   top1_acc   top5_acc: 100%|██████████| 1/1 [00:00<00:00,
#                    all       0.75          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      92/500      2.62G    0.00206          6        320: 100%|██████████| 4/4 [0
#                classes   top1_acc   top5_acc: 100%|██████████| 1/1 [00:00<00:00,
#                    all       0.75          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      93/500      2.62G    0.01451          6        320: 100%|██████████| 4/4 [0
#                classes   top1_acc   top5_acc: 100%|██████████| 1/1 [00:00<00:00,
#                    all       0.75          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      94/500      2.62G  0.0007438          6        320: 100%|██████████| 4/4 [0
#                classes   top1_acc   top5_acc: 100%|██████████| 1/1 [00:00<00:00,
#                    all       0.75          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      95/500      2.62G  0.0008496          6        320: 100%|██████████| 4/4 [0
#                classes   top1_acc   top5_acc: 100%|██████████| 1/1 [00:00<00:00,
#                    all       0.75          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      96/500      2.62G    0.04774          6        320: 100%|██████████| 4/4 [0
#                classes   top1_acc   top5_acc: 100%|██████████| 1/1 [00:00<00:00,
#                    all       0.75          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      97/500      2.62G  0.0002369          6        320: 100%|██████████| 4/4 [0
#                classes   top1_acc   top5_acc: 100%|██████████| 1/1 [00:00<00:00,
#                    all       0.75          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      98/500      2.62G   0.001047          6        320: 100%|██████████| 4/4 [0
#                classes   top1_acc   top5_acc: 100%|██████████| 1/1 [00:00<00:00,
#                    all      0.625          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      99/500      2.62G   0.001134          6        320: 100%|██████████| 4/4 [0
#                classes   top1_acc   top5_acc: 100%|██████████| 1/1 [00:00<00:00,
#                    all       0.75          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#     100/500      2.62G   0.005016          6        320: 100%|██████████| 4/4 [0
#                classes   top1_acc   top5_acc: 100%|██████████| 1/1 [00:00<00:00,
#                    all      0.625          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#     101/500      2.62G   0.004487          6        320: 100%|██████████| 4/4 [0
#                classes   top1_acc   top5_acc: 100%|██████████| 1/1 [00:00<00:00,
#                    all       0.75          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#     102/500      2.62G   0.006772          6        320: 100%|██████████| 4/4 [0
#                classes   top1_acc   top5_acc: 100%|██████████| 1/1 [00:00<00:00,
#                    all       0.75          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#     103/500      2.62G   0.006171          6        320: 100%|██████████| 4/4 [0
#                classes   top1_acc   top5_acc: 100%|██████████| 1/1 [00:00<00:00,
#                    all       0.75          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#     104/500      2.62G   0.001273          6        320: 100%|██████████| 4/4 [0
#                classes   top1_acc   top5_acc: 100%|██████████| 1/1 [00:00<00:00,
#                    all      0.625          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#     105/500      2.62G  0.0009143          6        320: 100%|██████████| 4/4 [0
#                classes   top1_acc   top5_acc: 100%|██████████| 1/1 [00:00<00:00,
#                    all      0.625          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#     106/500      2.62G   0.002228          6        320: 100%|██████████| 4/4 [0
#                classes   top1_acc   top5_acc: 100%|██████████| 1/1 [00:00<00:00,
#                    all      0.625          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#     107/500      2.62G   0.001709          6        320: 100%|██████████| 4/4 [0
#                classes   top1_acc   top5_acc: 100%|██████████| 1/1 [00:00<00:00,
#                    all      0.625          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#     108/500      2.62G   0.001178          6        320: 100%|██████████| 4/4 [0
#                classes   top1_acc   top5_acc: 100%|██████████| 1/1 [00:00<00:00,
#                    all      0.625          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#     109/500      2.62G   0.000929          6        320: 100%|██████████| 4/4 [0
#                classes   top1_acc   top5_acc: 100%|██████████| 1/1 [00:00<00:00,
#                    all      0.625          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#     110/500      2.62G   0.003117          6        320: 100%|██████████| 4/4 [0
#                classes   top1_acc   top5_acc: 100%|██████████| 1/1 [00:00<00:00,
#                    all      0.625          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#     111/500      2.62G  0.0006366          6        320: 100%|██████████| 4/4 [0
#                classes   top1_acc   top5_acc: 100%|██████████| 1/1 [00:00<00:00,
#                    all      0.625          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#     112/500      2.62G  0.0004923          6        320: 100%|██████████| 4/4 [0
#                classes   top1_acc   top5_acc: 100%|██████████| 1/1 [00:00<00:00,
#                    all      0.625          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#     113/500      2.63G   0.001009          6        320: 100%|██████████| 4/4 [0
#                classes   top1_acc   top5_acc: 100%|██████████| 1/1 [00:00<00:00,
#                    all      0.625          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#     114/500      2.62G   0.000265          6        320: 100%|██████████| 4/4 [0
#                classes   top1_acc   top5_acc: 100%|██████████| 1/1 [00:00<00:00,
#                    all      0.625          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#     115/500      2.62G  0.0004652          6        320: 100%|██████████| 4/4 [0
#                classes   top1_acc   top5_acc: 100%|██████████| 1/1 [00:00<00:00,
#                    all      0.625          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#     116/500      2.62G  0.0003277          6        320: 100%|██████████| 4/4 [0
#                classes   top1_acc   top5_acc: 100%|██████████| 1/1 [00:00<00:00,
#                    all      0.625          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#     117/500      2.62G  0.0002985          6        320: 100%|██████████| 4/4 [0
#                classes   top1_acc   top5_acc: 100%|██████████| 1/1 [00:00<00:00,
#                    all      0.625          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#     118/500      2.62G  0.0004036          6        320: 100%|██████████| 4/4 [0
#                classes   top1_acc   top5_acc: 100%|██████████| 1/1 [00:00<00:00,
#                    all      0.625          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#     119/500      2.62G  0.0002218          6        320: 100%|██████████| 4/4 [0
#                classes   top1_acc   top5_acc: 100%|██████████| 1/1 [00:00<00:00,
#                    all      0.625          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#     120/500      2.62G   0.000468          6        320: 100%|██████████| 4/4 [0
#                classes   top1_acc   top5_acc: 100%|██████████| 1/1 [00:00<00:00,
#                    all       0.75          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#     121/500      2.62G  0.0001334          6        320: 100%|██████████| 4/4 [0
#                classes   top1_acc   top5_acc: 100%|██████████| 1/1 [00:00<00:00,
#                    all      0.625          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#     122/500      2.62G  0.0001546          6        320: 100%|██████████| 4/4 [0
#                classes   top1_acc   top5_acc: 100%|██████████| 1/1 [00:00<00:00,
#                    all      0.625          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#     123/500      2.62G  0.0001638          6        320: 100%|██████████| 4/4 [0
#                classes   top1_acc   top5_acc: 100%|██████████| 1/1 [00:00<00:00,
#                    all      0.625          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#     124/500      2.62G  0.0001755          6        320: 100%|██████████| 4/4 [0
#                classes   top1_acc   top5_acc: 100%|██████████| 1/1 [00:00<00:00,
#                    all      0.625          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#     125/500      2.62G   0.002128          6        320: 100%|██████████| 4/4 [0
#                classes   top1_acc   top5_acc: 100%|██████████| 1/1 [00:00<00:00,
#                    all      0.625          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#     126/500      2.62G  0.0004285          6        320: 100%|██████████| 4/4 [0
#                classes   top1_acc   top5_acc: 100%|██████████| 1/1 [00:00<00:00,
#                    all      0.625          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#     127/500      2.62G   0.005176          6        320: 100%|██████████| 4/4 [0
#                classes   top1_acc   top5_acc: 100%|██████████| 1/1 [00:00<00:00,
#                    all       0.75          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#     128/500      2.62G  0.0003785          6        320: 100%|██████████| 4/4 [0
#                classes   top1_acc   top5_acc: 100%|██████████| 1/1 [00:00<00:00,
#                    all       0.75          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#     129/500      2.62G   0.000189          6        320: 100%|██████████| 4/4 [0
#                classes   top1_acc   top5_acc: 100%|██████████| 1/1 [00:00<00:00,
#                    all       0.75          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#     130/500      2.62G   0.002149          6        320: 100%|██████████| 4/4 [0
#                classes   top1_acc   top5_acc: 100%|██████████| 1/1 [00:00<00:00,
#                    all       0.75          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#     131/500      2.62G   0.001084          6        320: 100%|██████████| 4/4 [0
#                classes   top1_acc   top5_acc: 100%|██████████| 1/1 [00:00<00:00,
#                    all      0.625          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#     132/500      2.62G   0.002151          6        320: 100%|██████████| 4/4 [0
#                classes   top1_acc   top5_acc: 100%|██████████| 1/1 [00:00<00:00,
#                    all       0.75          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#     133/500      2.62G    0.00107          6        320: 100%|██████████| 4/4 [0
#                classes   top1_acc   top5_acc: 100%|██████████| 1/1 [00:00<00:00,
#                    all       0.75          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#     134/500      2.62G   0.000912          6        320: 100%|██████████| 4/4 [0
#                classes   top1_acc   top5_acc: 100%|██████████| 1/1 [00:00<00:00,
#                    all       0.75          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#     135/500      2.62G    0.01393          6        320: 100%|██████████| 4/4 [0
#                classes   top1_acc   top5_acc: 100%|██████████| 1/1 [00:00<00:00,
#                    all      0.625          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#     136/500      2.62G  0.0004224          6        320: 100%|██████████| 4/4 [0
#                classes   top1_acc   top5_acc: 100%|██████████| 1/1 [00:00<00:00,
#                    all       0.75          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#     137/500      2.62G   0.004085          6        320: 100%|██████████| 4/4 [0
#                classes   top1_acc   top5_acc: 100%|██████████| 1/1 [00:00<00:00,
#                    all      0.625          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#     138/500      2.62G  0.0003775          6        320: 100%|██████████| 4/4 [0
#                classes   top1_acc   top5_acc: 100%|██████████| 1/1 [00:00<00:00,
#                    all       0.75          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#     139/500      2.62G     0.0373          6        320: 100%|██████████| 4/4 [0
#                classes   top1_acc   top5_acc: 100%|██████████| 1/1 [00:00<00:00,
#                    all       0.75          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#     140/500      2.62G    0.01684          6        320: 100%|██████████| 4/4 [0
#                classes   top1_acc   top5_acc: 100%|██████████| 1/1 [00:00<00:00,
#                    all       0.75          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#     141/500      2.62G    0.02038          6        320: 100%|██████████| 4/4 [0
#                classes   top1_acc   top5_acc: 100%|██████████| 1/1 [00:00<00:00,
#                    all       0.75          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#     142/500      2.62G   0.003401          6        320: 100%|██████████| 4/4 [0
#                classes   top1_acc   top5_acc: 100%|██████████| 1/1 [00:00<00:00,
#                    all       0.75          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#     143/500      2.62G   0.005108          6        320: 100%|██████████| 4/4 [0
#                classes   top1_acc   top5_acc: 100%|██████████| 1/1 [00:00<00:00,
#                    all       0.75          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#     144/500      2.62G    0.02424          6        320: 100%|██████████| 4/4 [0
#                classes   top1_acc   top5_acc: 100%|██████████| 1/1 [00:00<00:00,
#                    all      0.625          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#     145/500      2.62G    0.03575          6        320: 100%|██████████| 4/4 [0
#                classes   top1_acc   top5_acc: 100%|██████████| 1/1 [00:00<00:00,
#                    all      0.625          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#     146/500      2.62G   0.002333          6        320: 100%|██████████| 4/4 [0
#                classes   top1_acc   top5_acc: 100%|██████████| 1/1 [00:00<00:00,
#                    all      0.625          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#     147/500      2.62G    0.03704          6        320: 100%|██████████| 4/4 [0
#                classes   top1_acc   top5_acc: 100%|██████████| 1/1 [00:00<00:00,
#                    all      0.625          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#     148/500      2.62G   0.003221          6        320: 100%|██████████| 4/4 [0
#                classes   top1_acc   top5_acc: 100%|██████████| 1/1 [00:00<00:00,
#                    all      0.625          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#     149/500      2.62G  0.0009507          6        320: 100%|██████████| 4/4 [0
#                classes   top1_acc   top5_acc: 100%|██████████| 1/1 [00:00<00:00,
#                    all      0.625          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#     150/500      2.62G   0.004791          6        320: 100%|██████████| 4/4 [0
#                classes   top1_acc   top5_acc: 100%|██████████| 1/1 [00:00<00:00,
#                    all      0.625          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#     151/500      2.62G  0.0007524          6        320: 100%|██████████| 4/4 [0
#                classes   top1_acc   top5_acc: 100%|██████████| 1/1 [00:00<00:00,
#                    all      0.625          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#     152/500      2.62G   0.002905          6        320: 100%|██████████| 4/4 [0
#                classes   top1_acc   top5_acc: 100%|██████████| 1/1 [00:00<00:00,
#                    all      0.625          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#     153/500      2.62G   0.002847          6        320: 100%|██████████| 4/4 [0
#                classes   top1_acc   top5_acc: 100%|██████████| 1/1 [00:00<00:00,
#                    all      0.625          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#     154/500      2.62G   0.004609          6        320: 100%|██████████| 4/4 [0
#                classes   top1_acc   top5_acc: 100%|██████████| 1/1 [00:00<00:00,
#                    all      0.625          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#     155/500      2.62G  0.0009653          6        320: 100%|██████████| 4/4 [0
#                classes   top1_acc   top5_acc: 100%|██████████| 1/1 [00:00<00:00,
#                    all      0.625          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#     156/500      2.62G   0.002862          6        320: 100%|██████████| 4/4 [0
#                classes   top1_acc   top5_acc: 100%|██████████| 1/1 [00:00<00:00,
#                    all      0.625          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#     157/500      2.62G   0.001226          6        320: 100%|██████████| 4/4 [0
#                classes   top1_acc   top5_acc: 100%|██████████| 1/1 [00:00<00:00,
#                    all       0.75          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#     158/500      2.62G   0.001123          6        320: 100%|██████████| 4/4 [0
#                classes   top1_acc   top5_acc: 100%|██████████| 1/1 [00:00<00:00,
#                    all       0.75          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#     159/500      2.62G   0.001321          6        320: 100%|██████████| 4/4 [0
#                classes   top1_acc   top5_acc: 100%|██████████| 1/1 [00:00<00:00,
#                    all       0.75          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#     160/500      2.62G   0.004243          6        320: 100%|██████████| 4/4 [0
#                classes   top1_acc   top5_acc: 100%|██████████| 1/1 [00:00<00:00,
#                    all       0.75          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#     161/500      2.62G   0.001674          6        320: 100%|██████████| 4/4 [0
#                classes   top1_acc   top5_acc: 100%|██████████| 1/1 [00:00<00:00,
#                    all       0.75          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#     162/500      2.62G  0.0001887          6        320: 100%|██████████| 4/4 [0
#                classes   top1_acc   top5_acc: 100%|██████████| 1/1 [00:00<00:00,
#                    all       0.75          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#     163/500      2.62G  0.0002252          6        320: 100%|██████████| 4/4 [0
#                classes   top1_acc   top5_acc: 100%|██████████| 1/1 [00:00<00:00,
#                    all      0.875          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#     164/500      2.62G  0.0005883          6        320: 100%|██████████| 4/4 [0
#                classes   top1_acc   top5_acc: 100%|██████████| 1/1 [00:00<00:00,
#                    all      0.875          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#     165/500      2.62G   0.000205          6        320: 100%|██████████| 4/4 [0
#                classes   top1_acc   top5_acc: 100%|██████████| 1/1 [00:00<00:00,
#                    all      0.875          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#     166/500      2.62G  0.0001905          6        320: 100%|██████████| 4/4 [0
#                classes   top1_acc   top5_acc: 100%|██████████| 1/1 [00:00<00:00,
#                    all      0.875          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#     167/500      2.62G  0.0001485          6        320: 100%|██████████| 4/4 [0
# ...
#                    all       0.75          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#     305/500      2.62G  9.663e-05          6        320: 100%|██████████| 4/4 [0
#                classes   top1_acc   top5_acc: 100%|██████████| 1/1 [00:00<00:00,
#                    all       0.75          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#     306/500      2.62G  2.011e-05          6        320: 100%|██████████| 4/4 [0
#                classes   top1_acc   top5_acc: 100%|██████████| 1/1 [00:00<00:00,
#                    all       0.75          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#     307/500      2.62G  2.705e-05          6        320: 100%|██████████| 4/4 [0
#                classes   top1_acc   top5_acc: 100%|██████████| 1/1 [00:00<00:00,
#                    all       0.75          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#     308/500      2.62G  0.0001217          6        320: 100%|██████████| 4/4 [0
#                classes   top1_acc   top5_acc: 100%|██████████| 1/1 [00:00<00:00,
#                    all       0.75          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#     309/500      2.62G  0.0001104          6        320: 100%|██████████| 4/4 [0
#                classes   top1_acc   top5_acc: 100%|██████████| 1/1 [00:00<00:00,
#                    all       0.75          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#     310/500      2.62G   0.000275          6        320: 100%|██████████| 4/4 [0
#                classes   top1_acc   top5_acc: 100%|██████████| 1/1 [00:00<00:00,
#                    all       0.75          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#     311/500      2.62G  2.442e-05          6        320: 100%|██████████| 4/4 [0
#                classes   top1_acc   top5_acc: 100%|██████████| 1/1 [00:00<00:00,
#                    all       0.75          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#     312/500      2.62G  1.684e-05          6        320: 100%|██████████| 4/4 [0
#                classes   top1_acc   top5_acc: 100%|██████████| 1/1 [00:00<00:00,
#                    all       0.75          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#     313/500      2.62G  2.139e-05          6        320: 100%|██████████| 4/4 [0
#                classes   top1_acc   top5_acc: 100%|██████████| 1/1 [00:00<00:00,
#                    all       0.75          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#     314/500      2.62G  2.214e-05          6        320: 100%|██████████| 4/4 [0
#                classes   top1_acc   top5_acc: 100%|██████████| 1/1 [00:00<00:00,
#                    all       0.75          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#     315/500      2.62G  0.0001405          6        320: 100%|██████████| 4/4 [0
#                classes   top1_acc   top5_acc: 100%|██████████| 1/1 [00:00<00:00,
#                    all       0.75          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#     316/500      2.62G  2.275e-05          6        320: 100%|██████████| 4/4 [0
#                classes   top1_acc   top5_acc: 100%|██████████| 1/1 [00:00<00:00,
#                    all       0.75          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#     317/500      2.62G  2.375e-05          6        320: 100%|██████████| 4/4 [0
#                classes   top1_acc   top5_acc: 100%|██████████| 1/1 [00:00<00:00,
#                    all       0.75          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#     318/500      2.62G  2.789e-05          6        320: 100%|██████████| 4/4 [0
#                classes   top1_acc   top5_acc: 100%|██████████| 1/1 [00:00<00:00,
#                    all       0.75          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#     319/500      2.62G  1.598e-05          6        320: 100%|██████████| 4/4 [0
#                classes   top1_acc   top5_acc: 100%|██████████| 1/1 [00:00<00:00,
#                    all       0.75          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#     320/500      2.62G  8.596e-05          6        320: 100%|██████████| 4/4 [0
#                classes   top1_acc   top5_acc: 100%|██████████| 1/1 [00:00<00:00,
#                    all       0.75          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#     321/500      2.62G  0.0001761          6        320: 100%|██████████| 4/4 [0
#                classes   top1_acc   top5_acc: 100%|██████████| 1/1 [00:00<00:00,
#                    all       0.75          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#     322/500      2.62G  5.906e-05          6        320: 100%|██████████| 4/4 [0
#                classes   top1_acc   top5_acc: 100%|██████████| 1/1 [00:00<00:00,
#                    all       0.75          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#     323/500      2.62G  6.061e-06          6        320: 100%|██████████| 4/4 [0
#                classes   top1_acc   top5_acc: 100%|██████████| 1/1 [00:00<00:00,
#                    all       0.75          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#     324/500      2.62G   7.07e-05          6        320: 100%|██████████| 4/4 [0
#                classes   top1_acc   top5_acc: 100%|██████████| 1/1 [00:00<00:00,
#                    all       0.75          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#     325/500      2.62G  3.222e-05          6        320: 100%|██████████| 4/4 [0
#                classes   top1_acc   top5_acc: 100%|██████████| 1/1 [00:00<00:00,
#                    all       0.75          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#     326/500      2.62G   1.39e-05          6        320: 100%|██████████| 4/4 [0
#                classes   top1_acc   top5_acc: 100%|██████████| 1/1 [00:00<00:00,
#                    all       0.75          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#     327/500      2.62G   1.16e-05          6        320: 100%|██████████| 4/4 [0
#                classes   top1_acc   top5_acc: 100%|██████████| 1/1 [00:00<00:00,
#                    all      0.625          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#     328/500      2.62G   7.57e-05          6        320: 100%|██████████| 4/4 [0
#                classes   top1_acc   top5_acc: 100%|██████████| 1/1 [00:00<00:00,
#                    all      0.625          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#     329/500      2.63G  1.359e-05          6        320: 100%|██████████| 4/4 [0
#                classes   top1_acc   top5_acc: 100%|██████████| 1/1 [00:00<00:00,
#                    all      0.625          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#     330/500      2.62G  4.741e-05          6        320: 100%|██████████| 4/4 [0
#                classes   top1_acc   top5_acc: 100%|██████████| 1/1 [00:00<00:00,
#                    all      0.625          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#     331/500      2.62G  2.155e-05          6        320: 100%|██████████| 4/4 [0
#                classes   top1_acc   top5_acc: 100%|██████████| 1/1 [00:00<00:00,
#                    all      0.625          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#     332/500      2.62G  1.407e-05          6        320: 100%|██████████| 4/4 [0
#                classes   top1_acc   top5_acc: 100%|██████████| 1/1 [00:00<00:00,
#                    all      0.625          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#     333/500      2.62G   1.38e-05          6        320: 100%|██████████| 4/4 [0
#                classes   top1_acc   top5_acc: 100%|██████████| 1/1 [00:00<00:00,
#                    all      0.625          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#     334/500      2.62G  1.578e-05          6        320: 100%|██████████| 4/4 [0
#                classes   top1_acc   top5_acc: 100%|██████████| 1/1 [00:00<00:00,
#                    all      0.625          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#     335/500      2.62G  3.201e-05          6        320: 100%|██████████| 4/4 [0
#                classes   top1_acc   top5_acc: 100%|██████████| 1/1 [00:00<00:00,
#                    all      0.625          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#     336/500      2.62G  5.005e-05          6        320: 100%|██████████| 4/4 [0
#                classes   top1_acc   top5_acc: 100%|██████████| 1/1 [00:00<00:00,
#                    all      0.625          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#     337/500      2.62G  2.203e-05          6        320: 100%|██████████| 4/4 [0
#                classes   top1_acc   top5_acc: 100%|██████████| 1/1 [00:00<00:00,
#                    all      0.625          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#     338/500      2.62G   0.001485          6        320: 100%|██████████| 4/4 [0
#                classes   top1_acc   top5_acc: 100%|██████████| 1/1 [00:00<00:00,
#                    all      0.625          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#     339/500      2.62G  0.0001155          6        320: 100%|██████████| 4/4 [0
#                classes   top1_acc   top5_acc: 100%|██████████| 1/1 [00:00<00:00,
#                    all      0.625          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#     340/500      2.62G  1.693e-05          6        320: 100%|██████████| 4/4 [0
#                classes   top1_acc   top5_acc: 100%|██████████| 1/1 [00:00<00:00,
#                    all      0.625          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#     341/500      2.62G  1.622e-05          6        320: 100%|██████████| 4/4 [0
#                classes   top1_acc   top5_acc: 100%|██████████| 1/1 [00:00<00:00,
#                    all      0.625          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#     342/500      2.62G  7.148e-06          6        320: 100%|██████████| 4/4 [0
#                classes   top1_acc   top5_acc: 100%|██████████| 1/1 [00:00<00:00,
#                    all      0.625          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#     343/500      2.62G  2.521e-05          6        320: 100%|██████████| 4/4 [0
#                classes   top1_acc   top5_acc: 100%|██████████| 1/1 [00:00<00:00,
#                    all      0.625          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#     344/500      2.62G  5.536e-05          6        320: 100%|██████████| 4/4 [0
#                classes   top1_acc   top5_acc: 100%|██████████| 1/1 [00:00<00:00,
#                    all      0.625          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#     345/500      2.62G  1.584e-05          6        320: 100%|██████████| 4/4 [0
#                classes   top1_acc   top5_acc: 100%|██████████| 1/1 [00:00<00:00,
#                    all      0.625          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#     346/500      2.62G  1.732e-05          6        320: 100%|██████████| 4/4 [0
#                classes   top1_acc   top5_acc: 100%|██████████| 1/1 [00:00<00:00,
#                    all      0.625          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#     347/500      2.62G  1.872e-05          6        320: 100%|██████████| 4/4 [0
#                classes   top1_acc   top5_acc: 100%|██████████| 1/1 [00:00<00:00,
#                    all      0.625          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#     348/500      2.62G  3.045e-05          6        320: 100%|██████████| 4/4 [0
#                classes   top1_acc   top5_acc: 100%|██████████| 1/1 [00:00<00:00,
#                    all      0.625          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#     349/500      2.62G  0.0001488          6        320: 100%|██████████| 4/4 [0
#                classes   top1_acc   top5_acc: 100%|██████████| 1/1 [00:00<00:00,
#                    all      0.625          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#     350/500      2.62G  0.0002104          6        320: 100%|██████████| 4/4 [0
#                classes   top1_acc   top5_acc: 100%|██████████| 1/1 [00:00<00:00,
#                    all      0.625          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#     351/500      2.62G  1.592e-05          6        320: 100%|██████████| 4/4 [0
#                classes   top1_acc   top5_acc: 100%|██████████| 1/1 [00:00<00:00,
#                    all       0.75          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#     352/500      2.62G  2.244e-05          6        320: 100%|██████████| 4/4 [0
#                classes   top1_acc   top5_acc: 100%|██████████| 1/1 [00:00<00:00,
#                    all       0.75          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#     353/500      2.62G  1.477e-05          6        320: 100%|██████████| 4/4 [0
#                classes   top1_acc   top5_acc: 100%|██████████| 1/1 [00:00<00:00,
#                    all      0.625          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#     354/500      2.62G  8.907e-06          6        320: 100%|██████████| 4/4 [0
#                classes   top1_acc   top5_acc: 100%|██████████| 1/1 [00:00<00:00,
#                    all      0.625          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#     355/500      2.62G  2.961e-05          6        320: 100%|██████████| 4/4 [0
#                classes   top1_acc   top5_acc: 100%|██████████| 1/1 [00:00<00:00,
#                    all      0.625          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#     356/500      2.62G  2.174e-05          6        320: 100%|██████████| 4/4 [0
#                classes   top1_acc   top5_acc: 100%|██████████| 1/1 [00:00<00:00,
#                    all      0.625          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#     357/500      2.62G  3.869e-05          6        320: 100%|██████████| 4/4 [0
#                classes   top1_acc   top5_acc: 100%|██████████| 1/1 [00:00<00:00,
#                    all      0.625          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#     358/500      2.62G  1.315e-05          6        320: 100%|██████████| 4/4 [0
#                classes   top1_acc   top5_acc: 100%|██████████| 1/1 [00:00<00:00,
#                    all      0.625          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#     359/500      2.62G  2.049e-05          6        320: 100%|██████████| 4/4 [0
#                classes   top1_acc   top5_acc: 100%|██████████| 1/1 [00:00<00:00,
#                    all       0.75          1
# ^C
# Traceback (most recent call last):
#   File "/home/twilight/anaconda3/envs/USDA2023/bin/yolo", line 10, in <module>
#     sys.exit(entrypoint())
#              ^^^^^^^^^^^^
#   File "/home/twilight/anaconda3/envs/USDA2023/lib/python3.11/site-packages/ultralytics/cfg/__init__.py", line 407, in entrypoint
#     getattr(model, mode)(**overrides)  # default args from model
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/twilight/anaconda3/envs/USDA2023/lib/python3.11/site-packages/ultralytics/engine/model.py", line 372, in train
#     self.trainer.train()
#   File "/home/twilight/anaconda3/envs/USDA2023/lib/python3.11/site-packages/ultralytics/engine/trainer.py", line 192, in train
#     self._do_train(world_size)
#   File "/home/twilight/anaconda3/envs/USDA2023/lib/python3.11/site-packages/ultralytics/engine/trainer.py", line 378, in _do_train
#     self.save_model()
#   File "/home/twilight/anaconda3/envs/USDA2023/lib/python3.11/site-packages/ultralytics/engine/trainer.py", line 427, in save_model
#     torch.save(ckpt, self.last, pickle_module=pickle)
#   File "/home/twilight/anaconda3/envs/USDA2023/lib/python3.11/site-packages/torch/serialization.py", line 441, in save
#     _save(obj, opened_zipfile, pickle_module, pickle_protocol)
#   File "/home/twilight/anaconda3/envs/USDA2023/lib/python3.11/site-packages/torch/serialization.py", line 668, in _save
#     zip_file.write_record(name, storage.data_ptr(), num_bytes)
# KeyboardInterrupt

# %%
# !yolo classify val model="./Training/2023-10-8/train/weights/best.pt" data="./Datasets/With Secchi/_Processed/" project="./Training/2023-10-8"
# Out:
# WARNING ⚠️ 'ultralytics.yolo.v8' is deprecated since '8.0.136' and will be removed in '8.1.0'. Please use 'ultralytics.models.yolo' instead.
# WARNING ⚠️ 'ultralytics.yolo.cfg' is deprecated since '8.0.136' and will be removed in '8.1.0'. Please use 'ultralytics.cfg' instead.
# Ultralytics YOLOv8.0.138 🚀 Python-3.11.4 torch-2.0.1 CUDA:0 (NVIDIA GeForce RTX 4080, 16376MiB)
# YOLOv8l-cls summary (fused): 133 layers, 36190981 parameters, 0 gradients
# /home/twilight/anaconda3/envs/USDA2023/lib/python3.11/site-packages/torch/nn/modules/conv.py:459: UserWarning: Applied workaround for CuDNN issue, install nvrtc.so (Triggered internally at /opt/conda/conda-bld/pytorch_1682343995622/work/aten/src/ATen/native/cudnn/Conv_v8.cpp:80.)
#   return F.conv2d(input, weight, bias, self.stride,
#                classes   top1_acc   top5_acc: 100%|██████████| 1/1 [00:04<00:00,
#                    all      0.875          1
# Speed: 0.1ms preprocess, 5.1ms inference, 0.0ms loss, 0.0ms postprocess per image
# Results saved to Training/2023-10-8/val2

# %%
# Inference
# !yolo task=classify mode=predict model="./Training/2023-10-8/train/weights/best.pt" conf=0.5 source="./Datasets/With Secchi/_Processed/val/**/*" project="./Training/2023-10-8"
# Out:
# WARNING ⚠️ 'ultralytics.yolo.v8' is deprecated since '8.0.136' and will be removed in '8.1.0'. Please use 'ultralytics.models.yolo' instead.
# WARNING ⚠️ 'ultralytics.yolo.cfg' is deprecated since '8.0.136' and will be removed in '8.1.0'. Please use 'ultralytics.cfg' instead.
# Ultralytics YOLOv8.0.138 🚀 Python-3.11.4 torch-2.0.1 CUDA:0 (NVIDIA GeForce RTX 4080, 16376MiB)
# YOLOv8l-cls summary (fused): 133 layers, 36190981 parameters, 0 gradients
#
# /home/twilight/anaconda3/envs/USDA2023/lib/python3.11/site-packages/torch/nn/modules/conv.py:459: UserWarning: Applied workaround for CuDNN issue, install nvrtc.so (Triggered internally at /opt/conda/conda-bld/pytorch_1682343995622/work/aten/src/ATen/native/cudnn/Conv_v8.cpp:80.)
#   return F.conv2d(input, weight, bias, self.stride,
# image 1/8 /home/twilight/Honors Research Project/AI_Turbidity_Honors2023-4/Datasets/With Secchi/_Processed/val/0-10/P1010004.JPG: 320x320 0-10 1.00, 22-32 0.00, 11-21 0.00, 33-43 0.00, 44-55 0.00, 3.4ms
# image 2/8 /home/twilight/Honors Research Project/AI_Turbidity_Honors2023-4/Datasets/With Secchi/_Processed/val/0-10/P1010040.JPG: 320x320 0-10 1.00, 22-32 0.00, 33-43 0.00, 44-55 0.00, 11-21 0.00, 3.3ms
# image 3/8 /home/twilight/Honors Research Project/AI_Turbidity_Honors2023-4/Datasets/With Secchi/_Processed/val/0-10/P1010055.JPG: 320x320 0-10 1.00, 22-32 0.00, 33-43 0.00, 44-55 0.00, 11-21 0.00, 4.1ms
# image 4/8 /home/twilight/Honors Research Project/AI_Turbidity_Honors2023-4/Datasets/With Secchi/_Processed/val/0-10/P1010056.JPG: 320x320 0-10 1.00, 33-43 0.00, 11-21 0.00, 22-32 0.00, 44-55 0.00, 3.3ms
# image 5/8 /home/twilight/Honors Research Project/AI_Turbidity_Honors2023-4/Datasets/With Secchi/_Processed/val/11-21/P1010011.JPG: 320x320 11-21 0.62, 33-43 0.18, 22-32 0.15, 0-10 0.04, 44-55 0.00, 3.4ms
# image 6/8 /home/twilight/Honors Research Project/AI_Turbidity_Honors2023-4/Datasets/With Secchi/_Processed/val/22-32/P1010068.JPG: 320x320 22-32 0.63, 44-55 0.17, 33-43 0.14, 0-10 0.04, 11-21 0.01, 3.1ms
# image 7/8 /home/twilight/Honors Research Project/AI_Turbidity_Honors2023-4/Datasets/With Secchi/_Processed/val/33-43/P1010014.JPG: 320x320 44-55 0.76, 33-43 0.16, 22-32 0.05, 0-10 0.02, 11-21 0.02, 3.4ms
# image 8/8 /home/twilight/Honors Research Project/AI_Turbidity_Honors2023-4/Datasets/With Secchi/_Processed/val/44-55/P1010024.JPG: 320x320 44-55 1.00, 33-43 0.00, 0-10 0.00, 11-21 0.00, 22-32 0.00, 2.8ms
# Speed: 1.1ms preprocess, 3.4ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 320)
# Results saved to Training/2023-10-8/predict
